# %%
import pandas as pd
import numpy as np
from datetime import timedelta, datetime

from nemosis import static_table, dynamic_data_compiler
import plotly.express as px

raw_data_cache = '/Volumes/T7/NEMO_data'

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Definition
# Residual demand: RD_i(p) = Total_Demand - Sum(Supply_j(p)) for all j != i
#
# Where:
#
# Total_Demand is the perfectly inelastic balancing demand in that auction
# Supply_j(p) are the supply bids submitted by all other firms j ≠ i
#
# # Steps
# Get the total balancing demand for the auction from the data
# Collect all supply bids from rival firms in the auction
# Subtract rival supply from total demand to get residual demand
# This creates a step function since bids are step functions
# Finally, smooth this residual demand
#
# We're again going to first start with finding residual demand for a single Origin energy coal plant on 2021-04-07 18:05:00

# %%
dispatch_load = dynamic_data_compiler(
    start_time='2021/03/01 00:00:00',
    end_time='2021/04/10 00:00:00',
    table_name='DISPATCHLOAD',
    raw_data_location=raw_data_cache
)
# Out:
# INFO: Compiling data for table DISPATCHLOAD
# WARNING: {'LOWER1SEC', 'RAISE1SEC'} not in /Volumes/T7/NEMO_data/PUBLIC_DVD_DISPATCHLOAD_202102010000.feather. Loading ['SETTLEMENTDATE', 'DUID', 'INTERVENTION', 'DISPATCHMODE', 'AGCSTATUS', 'INITIALMW', 'TOTALCLEARED', 'RAMPDOWNRATE', 'RAMPUPRATE', 'LOWER5MIN', 'LOWER60SEC', 'LOWER6SEC', 'RAISE5MIN', 'RAISE60SEC', 'RAISE6SEC', 'LOWERREG', 'RAISEREG', 'AVAILABILITY', 'RAISEREGENABLEMENTMAX', 'RAISEREGENABLEMENTMIN', 'LOWERREGENABLEMENTMAX', 'LOWERREGENABLEMENTMIN', 'SEMIDISPATCHCAP']
# ...

# %%
dispatch_load
# Out:
#             SETTLEMENTDATE     DUID  INTERVENTION  DISPATCHMODE  AGCSTATUS  \
# 0      2021-03-01 00:05:00   AGLHAL             0             0          0
# 1      2021-03-01 00:05:00   AGLSOM             0             0          0
# 2      2021-03-01 00:05:00  ANGAST1             0             0          0
# 3      2021-03-01 00:05:00    APD01             0             0          0
# 4      2021-03-01 00:05:00    ARWF1             0             0          0
# ...                    ...      ...           ...           ...        ...
# 914971 2021-04-10 00:00:00  YENDWF1             0             0          0
# 914972 2021-04-10 00:00:00    YWPS1             0             0          0
# 914973 2021-04-10 00:00:00    YWPS2             0             0          0
# 914974 2021-04-10 00:00:00    YWPS3             0             0          1
# 914975 2021-04-10 00:00:00    YWPS4             0             0          1
#
# ...
