# %%
import nemseer

# %%
# # Define the parameters for the data you want to retrieve
# run_start = "2025/02/11 00:00"
# run_end = "2025/02/11 23:30"
# forecasted_start = "2025/02/11 00:00"
# forecasted_end = "2025/02/11 23:30"
# forecast_type = "PREDISPATCH"
# tables = ["OFFERTRK"]
# raw_cache = '/Volumes/T7/NEMSEER_data'

# # Compile the data
# data = nemseer.compile_data(
#     run_start=run_start,
#     run_end=run_end,
#     forecasted_start=forecasted_start,
#     forecasted_end=forecasted_end,
#     forecast_type=forecast_type,
#     tables=tables,
#     raw_cache=raw_cache,
#     data_format="df",
# )

# # Access the OFFERTRK DataFrame
# offertrk_df = data["OFFERTRK"]

# # Filter the DataFrame for the specific power station using its DUID
# duid = "YOUR_GENERATOR_DUID"
# generator_schedule = offertrk_df[offertrk_df["DUID"] == duid]

# # Display the schedule
# print(generator_schedule)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 raw_cache = '/Volumes/T7/NEMSEER_data'
#      10 # Compile the data
# ---> 11 data = nemseer.compile_data(
#      12     run_start=run_start,
#      13     run_end=run_end,
#      14     forecasted_start=forecasted_start,
#      15     forecasted_end=forecasted_end,
#      16     forecast_type=forecast_type,
#      17     tables=tables,
#      18     raw_cache=raw_cache,
#      19     data_format="df",
#      20 )
#      22 # Access the OFFERTRK DataFrame
#      23 offertrk_df = data["OFFERTRK"]
#
# File /Applications/anaconda3/lib/python3.11/site-packages/nemseer/nemseer.py:185, in compile_data(run_start, run_end, forecasted_start, forecasted_end, forecast_type, tables, raw_cache, processed_cache, data_format)
#     183 compiler = DataCompiler.from_Query(query)
#     184 if compiler.raw_tables:
# ...

# %%
from pathlib import Path

import nemosis
from nemseer import compile_data, generate_runtimes


import plotly.graph_objects as go

import matplotlib.pyplot as plt

import hvplot.xarray
hvplot.extension("plotly")

# for some advanced colour manipulation
from matplotlib.colors import to_hex
import numpy as np

# plotly rendering
import plotly.io as pio
import plotly.express as px
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# ...

# %%
(start, end) = ("2022/07/14 16:55:00", "2022/07/14 19:00:00")

# %%
p5_run_start, p5_run_end = generate_runtimes(start, end,
                                             "P5MIN")
p5_data = compile_data(p5_run_start, p5_run_end, start, end,
                       "P5MIN", "REGIONSOLUTION", raw_cache="nemseer_cache/",
                       data_format="xr")
p5_region = p5_data["REGIONSOLUTION"]
# .sel() is a lot like .loc() for pandas
# We then use ["TOTALDEMAND"] to acces that specific variable
p5_demand_forecasts = p5_region.sel(
    forecasted_time=slice(start, end),
    REGIONID="NSW1"
)["TOTALDEMAND"]
# Out:
# INFO: Downloading and unzipping REGIONSOLUTION for 7/2022
# PUBLIC_DVD_P5MIN_REGIONSOLUTION_202207010000.zip:   0%|          | 0/43840166 [00:00<?, ?it/s]
# INFO: Converting PUBLIC_DVD_P5MIN_REGIONSOLUTION_202207010000.CSV to parquet
# INFO: Converting REGIONSOLUTION data to xarray.
# WARNING: High-dimensional data. Large datetime requests may result in the Python process being killed by the system
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 p5_run_start, p5_run_end = generate_runtimes(start, end,
#       2                                              "P5MIN")
# ----> 3 p5_data = compile_data(p5_run_start, p5_run_end, start, end,
#       4                        "P5MIN", "REGIONSOLUTION", raw_cache="nemseer_cache/",
#       5                        data_format="xr")
#       6 p5_region = p5_data["REGIONSOLUTION"]
# ...

# %%
p5_demand_forecasts.plot();
